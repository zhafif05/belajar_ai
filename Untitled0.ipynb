# %%
import matplotlib.pyplot as plt
x=[1,3,2,1,3,1]
y=[2,3.3,4.5,3.3,2,2]
plt.xlabel('po')
plt.ylabel('po')
plt.plot(x,y,"maroon",marker="*",markersize="10",markeredgecolor="blue")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


a = [60, 70, 80, 90, 100]
b = [55, 65, 60, 75, 95]

x = np.arange(len(a))
width = 0.35


plt.bar(x - width/2, b, width=width, color='r', label='Rakyat')


plt.bar(x + width/2, a, width=width, color='g', label='Koruptor')


plt.xlabel('Overs')
plt.ylabel('Runs Scored')
plt.title('Scoring Chart Rakyat & Koruptor')
plt.xticks(x, ['1-10', '11-20', '21-30', '31-40', '41-50'])  # Label interval over


plt.legend()

plt.show()
